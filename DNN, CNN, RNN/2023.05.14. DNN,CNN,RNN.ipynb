# %%
import numpy as np
import pandas as pd

#!pip install soynlp
from soynlp.tokenizer import MaxScoreTokenizer
from soynlp.word import WordExtractor
from soynlp.tokenizer import LTokenizer

import os
import shutil

import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
from tensorflow.keras.layers import (
    Embedding,
    Flatten,
    GRU,
    Conv1D,
    Lambda,
    Dense,
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical


print(tf.__version__)

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

LOGDIR = "./text_models"
# Out:
# 2.12.0

# %%
data = pd.read_csv('review_dataset.csv',encoding='utf-8')
print(data.head())
#print(data['content'])
data['content'] = data['content'].apply(str)
# Out:
#                                              content  메뉴명
# 0  아이스 아메리카노는 단맛이나 크림 등이 없어서 맛이 진하다. 내 취향에 딱 맞아서 좋다.    0
# 1  아이스 아메리카노는 맛이 너무 진해서 좀 까다로운 편인데, 이곳은 정말 괜찮은 편이...    0
# 2  커피를 그다지 좋아하지 않는데, 이 아이스 아메리카노는 내가 시도한 커피 중에 제일...    0
# 3  아이스 아메리카노가 별로 맛이 없어서 실망했다. 커피 취향이 있는 사람들은 이곳에서...    0
# 4  저는 아이스 아메리카노에 누구보다도 예민한 편인데, 이곳에서는 항상 맛있게 마시고 ...    0

# %%
#!pip install -U pandas-profiling
corpus = data.content.apply(str)
word_extractor = WordExtractor()
word_extractor.train(corpus)
word_score = word_extractor.extract()
scores = {word:score.cohesion_forward for word, score in word_score.items()}
maxscore_tokenizer = MaxScoreTokenizer(scores=scores)

def soynlp_morphs(contents):
    return ' '.join(maxscore_tokenizer.tokenize(contents))
# Out:
# training was done. used memory 0.657 Gb
# all cohesion probabilities was computed. # words = 910
# all branching entropies was computed # words = 1703
# all accessor variety was computed # words = 1703

# %%
# %%time
data['soynlp_morphs_contents'] = data['content'].apply(soynlp_morphs)
# Out:
# CPU times: user 133 ms, sys: 0 ns, total: 133 ms
# Wall time: 145 ms

# %%
X = data.soynlp_morphs_contents
y = data.메뉴명

# %%
## X,y
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
sequences = tokenizer.texts_to_sequences(X)  ### vovab을 만들고 각 단어마다 고유번호를 매긴 후 번호를 순서에 따라 매핑하는 방법

# %%
word_to_index = tokenizer.word_index
VOCAB_SIZE = len(word_to_index) + 1  ##  padding 할때 필요한 0 index 추가

# %%
MAX_LEN = max(len(seq) for seq in sequences)
print(MAX_LEN)
# Out:
# 79

# %%
def encode_labels(sources):
    classes = [source for source in sources]
    #print(classes)
    one_hots = to_categorical(classes)
    #print(one_hots)
    return one_hots

# %%
def create_sequences(texts, max_len=MAX_LEN):
    sequences = tokenizer.texts_to_sequences(texts)
    padded_sequences = pad_sequences(sequences, max_len, padding='post')
    return padded_sequences

# %%
#print(y)
X_train, X_test, y_train, y_test = train_test_split(create_sequences(X), encode_labels(y), test_size=0.3, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=42)
#종속 변수의 클래스 수
N_CLASSES =4

# %%
def build_dnn_model(embed_dim):

    model = Sequential([
        Embedding(VOCAB_SIZE + 1, embed_dim, input_shape=[MAX_LEN]), 
        Lambda(lambda x: tf.reduce_mean(x, axis=1)), 
        Dense(100, activation='relu'),
        Dense(100, activation='relu'),
        Dense(N_CLASSES, activation='softmax')  ## activation=tf.nn.softmax
    ])

    model.compile(
        # optimizer=tf.keras.optimizers.Adam(
        #     learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
        #     name='Adam'
        # )
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# %%time
tf.random.set_seed(33) # tf 2.0에서 적용

MODEL_DIR = os.path.join(LOGDIR, 'dnn')
shutil.rmtree(MODEL_DIR, ignore_errors=True)

BATCH_SIZE = 300  #300
EPOCHS = 50 #50
EMBED_DIM = 100
PATIENCE = 0

dnn_model = build_dnn_model(embed_dim=EMBED_DIM)

dnn_history = dnn_model.fit(
    X_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_valid, y_valid),
    callbacks=[EarlyStopping(patience=PATIENCE), TensorBoard(MODEL_DIR)],
)

## tf 2.0 : 'accuracy', 'val_accuracy','loss', 'val_loss'
pd.DataFrame(dnn_history.history)[['loss', 'val_loss']].plot()
pd.DataFrame(dnn_history.history)[['accuracy', 'val_accuracy']].plot()

dnn_model.summary()
# Out:
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 1.3858 - accuracy: 0.2423 - val_loss: 1.3850 - val_accuracy: 0.2759
# Epoch 2/50
# 1/1 [==============================] - 0s 63ms/step - loss: 1.3844 - accuracy: 0.2423 - val_loss: 1.3840 - val_accuracy: 0.3103
# Epoch 3/50
# 1/1 [==============================] - 0s 69ms/step - loss: 1.3831 - accuracy: 0.2923 - val_loss: 1.3831 - val_accuracy: 0.5862
# Epoch 4/50
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3820 - accuracy: 0.6423 - val_loss: 1.3821 - val_accuracy: 0.5862
# Epoch 5/50
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3808 - accuracy: 0.6538 - val_loss: 1.3812 - val_accuracy: 0.4138
# Epoch 6/50
# 1/1 [==============================] - 0s 62ms/step - loss: 1.3797 - accuracy: 0.5038 - val_loss: 1.3804 - val_accuracy: 0.2414
# Epoch 7/50
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3785 - accuracy: 0.4192 - val_loss: 1.3795 - val_accuracy: 0.2414
# Epoch 8/50
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3774 - accuracy: 0.3846 - val_loss: 1.3786 - val_accuracy: 0.3103
# Epoch 9/50
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3762 - accuracy: 0.4077 - val_loss: 1.3776 - val_accuracy: 0.3448
# Epoch 10/50
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3749 - accuracy: 0.4423 - val_loss: 1.3766 - val_accuracy: 0.3793
# Epoch 11/50
# 1/1 [==============================] - 0s 72ms/step - loss: 1.3736 - accuracy: 0.5115 - val_loss: 1.3756 - val_accuracy: 0.4138
# Epoch 12/50
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3723 - accuracy: 0.5269 - val_loss: 1.3744 - val_accuracy: 0.4483
# Epoch 13/50
# 1/1 [==============================] - 0s 75ms/step - loss: 1.3708 - accuracy: 0.5308 - val_loss: 1.3731 - val_accuracy: 0.4138
# Epoch 14/50
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3693 - accuracy: 0.5308 - val_loss: 1.3718 - val_accuracy: 0.4138
# Epoch 15/50
# 1/1 [==============================] - 0s 72ms/step - loss: 1.3677 - accuracy: 0.5308 - val_loss: 1.3703 - val_accuracy: 0.4138
# Epoch 16/50
# 1/1 [==============================] - 0s 63ms/step - loss: 1.3660 - accuracy: 0.5269 - val_loss: 1.3686 - val_accuracy: 0.4138
# Epoch 17/50
# 1/1 [==============================] - 0s 60ms/step - loss: 1.3641 - accuracy: 0.5192 - val_loss: 1.3669 - val_accuracy: 0.4138
# Epoch 18/50
# 1/1 [==============================] - 0s 55ms/step - loss: 1.3621 - accuracy: 0.5154 - val_loss: 1.3650 - val_accuracy: 0.4483
# Epoch 19/50
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3601 - accuracy: 0.5038 - val_loss: 1.3631 - val_accuracy: 0.4483
# Epoch 20/50
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3580 - accuracy: 0.5038 - val_loss: 1.3612 - val_accuracy: 0.4138
# Epoch 21/50
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3559 - accuracy: 0.4923 - val_loss: 1.3593 - val_accuracy: 0.4138
# Epoch 22/50
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3537 - accuracy: 0.4923 - val_loss: 1.3572 - val_accuracy: 0.4138
# Epoch 23/50
# 1/1 [==============================] - 0s 69ms/step - loss: 1.3514 - accuracy: 0.4923 - val_loss: 1.3550 - val_accuracy: 0.4138
# Epoch 24/50
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3490 - accuracy: 0.4923 - val_loss: 1.3527 - val_accuracy: 0.4138
# Epoch 25/50
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3464 - accuracy: 0.4923 - val_loss: 1.3502 - val_accuracy: 0.4138
# Epoch 26/50
# 1/1 [==============================] - 0s 52ms/step - loss: 1.3437 - accuracy: 0.5000 - val_loss: 1.3475 - val_accuracy: 0.4138
# Epoch 27/50
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3409 - accuracy: 0.5000 - val_loss: 1.3447 - val_accuracy: 0.4138
# Epoch 28/50
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3379 - accuracy: 0.5000 - val_loss: 1.3418 - val_accuracy: 0.4138
# Epoch 29/50
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3347 - accuracy: 0.5000 - val_loss: 1.3387 - val_accuracy: 0.4138
# Epoch 30/50
# 1/1 [==============================] - 0s 72ms/step - loss: 1.3315 - accuracy: 0.5000 - val_loss: 1.3355 - val_accuracy: 0.4138
# Epoch 31/50
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3281 - accuracy: 0.5000 - val_loss: 1.3321 - val_accuracy: 0.4138
# Epoch 32/50
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3245 - accuracy: 0.5000 - val_loss: 1.3285 - val_accuracy: 0.4138
# Epoch 33/50
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3207 - accuracy: 0.5000 - val_loss: 1.3248 - val_accuracy: 0.4138
# Epoch 34/50
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3167 - accuracy: 0.5154 - val_loss: 1.3208 - val_accuracy: 0.4138
# Epoch 35/50
# 1/1 [==============================] - 0s 68ms/step - loss: 1.3126 - accuracy: 0.5231 - val_loss: 1.3167 - val_accuracy: 0.4483
# Epoch 36/50
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3082 - accuracy: 0.5231 - val_loss: 1.3123 - val_accuracy: 0.4483
# Epoch 37/50
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3037 - accuracy: 0.5308 - val_loss: 1.3076 - val_accuracy: 0.5172
# Epoch 38/50
# 1/1 [==============================] - 0s 56ms/step - loss: 1.2988 - accuracy: 0.5538 - val_loss: 1.3026 - val_accuracy: 0.5862
# Epoch 39/50
# 1/1 [==============================] - 0s 73ms/step - loss: 1.2937 - accuracy: 0.5615 - val_loss: 1.2973 - val_accuracy: 0.5862
# Epoch 40/50
# 1/1 [==============================] - 0s 74ms/step - loss: 1.2883 - accuracy: 0.5731 - val_loss: 1.2917 - val_accuracy: 0.5862
# Epoch 41/50
# 1/1 [==============================] - 0s 74ms/step - loss: 1.2826 - accuracy: 0.5808 - val_loss: 1.2858 - val_accuracy: 0.5862
# Epoch 42/50
# 1/1 [==============================] - 0s 72ms/step - loss: 1.2766 - accuracy: 0.5808 - val_loss: 1.2797 - val_accuracy: 0.5862
# Epoch 43/50
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2704 - accuracy: 0.5808 - val_loss: 1.2733 - val_accuracy: 0.6207
# Epoch 44/50
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2639 - accuracy: 0.5923 - val_loss: 1.2666 - val_accuracy: 0.6207
# Epoch 45/50
# 1/1 [==============================] - 0s 76ms/step - loss: 1.2571 - accuracy: 0.6038 - val_loss: 1.2597 - val_accuracy: 0.6552
# Epoch 46/50
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2501 - accuracy: 0.6154 - val_loss: 1.2525 - val_accuracy: 0.6897
# Epoch 47/50
# 1/1 [==============================] - 0s 74ms/step - loss: 1.2429 - accuracy: 0.6346 - val_loss: 1.2450 - val_accuracy: 0.6897
# Epoch 48/50
# 1/1 [==============================] - 0s 69ms/step - loss: 1.2354 - accuracy: 0.6500 - val_loss: 1.2372 - val_accuracy: 0.6552
# Epoch 49/50
# 1/1 [==============================] - 0s 64ms/step - loss: 1.2276 - accuracy: 0.6615 - val_loss: 1.2290 - val_accuracy: 0.6552
# Epoch 50/50
# 1/1 [==============================] - 0s 55ms/step - loss: 1.2194 - accuracy: 0.6654 - val_loss: 1.2206 - val_accuracy: 0.6552
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 79, 100)           98400
#
#  lambda_7 (Lambda)           (None, 100)               0
#
#  dense_21 (Dense)            (None, 100)               10100
#
#  dense_22 (Dense)            (None, 100)               10100
#
#  dense_23 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 119,004
# Trainable params: 119,004
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: user 5.21 s, sys: 216 ms, total: 5.43 s
# Wall time: 6.94 s

# %%
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.3849 - accuracy: 0.2192 - val_loss: 1.3665 - val_accuracy: 0.4828
# Epoch 2/50
# 1/1 [==============================] - 0s 123ms/step - loss: 1.3542 - accuracy: 0.5115 - val_loss: 1.3480 - val_accuracy: 0.4483
# Epoch 3/50
# 1/1 [==============================] - 0s 176ms/step - loss: 1.3258 - accuracy: 0.5615 - val_loss: 1.3284 - val_accuracy: 0.4483
# Epoch 4/50
# 1/1 [==============================] - 0s 238ms/step - loss: 1.2971 - accuracy: 0.5538 - val_loss: 1.3037 - val_accuracy: 0.4828
# Epoch 5/50
# 1/1 [==============================] - 0s 258ms/step - loss: 1.2659 - accuracy: 0.5731 - val_loss: 1.2730 - val_accuracy: 0.5172
# Epoch 6/50
# 1/1 [==============================] - 0s 238ms/step - loss: 1.2309 - accuracy: 0.6385 - val_loss: 1.2367 - val_accuracy: 0.5862
# Epoch 7/50
# 1/1 [==============================] - 0s 220ms/step - loss: 1.1917 - accuracy: 0.6577 - val_loss: 1.1950 - val_accuracy: 0.6207
# Epoch 8/50
# 1/1 [==============================] - 0s 237ms/step - loss: 1.1484 - accuracy: 0.7385 - val_loss: 1.1487 - val_accuracy: 0.7241
# Epoch 9/50
# 1/1 [==============================] - 0s 232ms/step - loss: 1.1010 - accuracy: 0.7962 - val_loss: 1.0986 - val_accuracy: 0.7931
# Epoch 10/50
# 1/1 [==============================] - 0s 243ms/step - loss: 1.0500 - accuracy: 0.8346 - val_loss: 1.0462 - val_accuracy: 0.8276
# Epoch 11/50
# 1/1 [==============================] - 0s 229ms/step - loss: 0.9963 - accuracy: 0.8346 - val_loss: 0.9928 - val_accuracy: 0.8276
# Epoch 12/50
# 1/1 [==============================] - 0s 246ms/step - loss: 0.9410 - accuracy: 0.8385 - val_loss: 0.9393 - val_accuracy: 0.8621
# Epoch 13/50
# 1/1 [==============================] - 0s 212ms/step - loss: 0.8839 - accuracy: 0.8423 - val_loss: 0.8859 - val_accuracy: 0.8621
# Epoch 14/50
# 1/1 [==============================] - 0s 249ms/step - loss: 0.8253 - accuracy: 0.8462 - val_loss: 0.8336 - val_accuracy: 0.8276
# Epoch 15/50
# 1/1 [==============================] - 0s 213ms/step - loss: 0.7674 - accuracy: 0.8385 - val_loss: 0.7831 - val_accuracy: 0.7931
# Epoch 16/50
# 1/1 [==============================] - 0s 222ms/step - loss: 0.7123 - accuracy: 0.8385 - val_loss: 0.7341 - val_accuracy: 0.7931
# Epoch 17/50
# 1/1 [==============================] - 0s 223ms/step - loss: 0.6600 - accuracy: 0.8385 - val_loss: 0.6863 - val_accuracy: 0.7931
# Epoch 18/50
# 1/1 [==============================] - 0s 232ms/step - loss: 0.6096 - accuracy: 0.8423 - val_loss: 0.6424 - val_accuracy: 0.8621
# Epoch 19/50
# 1/1 [==============================] - 0s 223ms/step - loss: 0.5620 - accuracy: 0.8500 - val_loss: 0.6053 - val_accuracy: 0.8621
# Epoch 20/50
# 1/1 [==============================] - 0s 243ms/step - loss: 0.5178 - accuracy: 0.8654 - val_loss: 0.5744 - val_accuracy: 0.8621
# Epoch 21/50
# 1/1 [==============================] - 0s 239ms/step - loss: 0.4754 - accuracy: 0.8769 - val_loss: 0.5463 - val_accuracy: 0.8276
# Epoch 22/50
# 1/1 [==============================] - 0s 234ms/step - loss: 0.4344 - accuracy: 0.8962 - val_loss: 0.5171 - val_accuracy: 0.8276
# Epoch 23/50
# 1/1 [==============================] - 0s 232ms/step - loss: 0.3949 - accuracy: 0.9038 - val_loss: 0.4857 - val_accuracy: 0.8621
# Epoch 24/50
# 1/1 [==============================] - 0s 155ms/step - loss: 0.3562 - accuracy: 0.9077 - val_loss: 0.4550 - val_accuracy: 0.8621
# Epoch 25/50
# 1/1 [==============================] - 0s 144ms/step - loss: 0.3188 - accuracy: 0.9154 - val_loss: 0.4275 - val_accuracy: 0.8621
# Epoch 26/50
# 1/1 [==============================] - 0s 133ms/step - loss: 0.2822 - accuracy: 0.9308 - val_loss: 0.4041 - val_accuracy: 0.8966
# Epoch 27/50
# 1/1 [==============================] - 0s 149ms/step - loss: 0.2473 - accuracy: 0.9538 - val_loss: 0.3811 - val_accuracy: 0.9310
# Epoch 28/50
# 1/1 [==============================] - 0s 139ms/step - loss: 0.2149 - accuracy: 0.9692 - val_loss: 0.3536 - val_accuracy: 0.9310
# Epoch 29/50
# 1/1 [==============================] - 0s 147ms/step - loss: 0.1844 - accuracy: 0.9769 - val_loss: 0.3233 - val_accuracy: 0.9310
# Epoch 30/50
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1566 - accuracy: 0.9923 - val_loss: 0.2942 - val_accuracy: 0.9310
# Epoch 31/50
# 1/1 [==============================] - 0s 145ms/step - loss: 0.1319 - accuracy: 0.9962 - val_loss: 0.2688 - val_accuracy: 0.9655
# Epoch 32/50
# 1/1 [==============================] - 0s 145ms/step - loss: 0.1102 - accuracy: 0.9962 - val_loss: 0.2472 - val_accuracy: 0.9655
# Epoch 33/50
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0913 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9655
# Epoch 34/50
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0752 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9655
# Epoch 35/50
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0618 - accuracy: 1.0000 - val_loss: 0.1919 - val_accuracy: 0.9655
# Epoch 36/50
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.1742 - val_accuracy: 0.9655
# Epoch 37/50
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9655
# Epoch 38/50
# 1/1 [==============================] - 0s 153ms/step - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9655
# Epoch 39/50
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.1296 - val_accuracy: 0.9655
# Epoch 40/50
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.1184 - val_accuracy: 0.9655
# Epoch 41/50
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.1088 - val_accuracy: 0.9655
# Epoch 42/50
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 0.9655
# Epoch 43/50
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9655
# Epoch 44/50
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9655
# Epoch 45/50
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9655
# Epoch 46/50
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9655
# Epoch 47/50
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 0.9655
# Epoch 48/50
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9655
# Epoch 49/50
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9655
# Epoch 50/50
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9655
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 79, 100)           98400
#
#  conv1d (Conv1D)             (None, 39, 200)           60200
#
#  flatten (Flatten)           (None, 7800)              0
#
#  dense_24 (Dense)            (None, 4)                 31204
#
# =================================================================
# Total params: 189,804
# Trainable params: 189,804
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: user 11.7 s, sys: 740 ms, total: 12.4 s
# Wall time: 10.5 s

# %%
#RNN

def build_rnn_model(embed_dim, units):

    model = Sequential([
        Embedding(VOCAB_SIZE + 1, embed_dim, input_shape=[MAX_LEN], mask_zero=True), 
        GRU(units), 
        Dense(N_CLASSES, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# %%time

tf.random.set_seed(33)

MODEL_DIR = os.path.join(LOGDIR, 'rnn')
shutil.rmtree(MODEL_DIR, ignore_errors=True)

EPOCHS = 50
BATCH_SIZE = 300
EMBED_DIM = 100
UNITS = 16
PATIENCE = 0

rnn_model = build_rnn_model(embed_dim=EMBED_DIM, units=UNITS)

history = rnn_model.fit(
    X_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_valid, y_valid),
    callbacks=[EarlyStopping(patience=PATIENCE), TensorBoard(MODEL_DIR)],
    use_multiprocessing=True ## OOM error out of memory error가 발생할때 True로 변경하여 준다 
)

pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()

rnn_model.summary()
# Out:
# Epoch 1/50
# 1/1 [==============================] - 6s 6s/step - loss: 1.3854 - accuracy: 0.3154 - val_loss: 1.3826 - val_accuracy: 0.2759
# Epoch 2/50
# 1/1 [==============================] - 0s 151ms/step - loss: 1.3770 - accuracy: 0.3654 - val_loss: 1.3765 - val_accuracy: 0.4138
# Epoch 3/50
# 1/1 [==============================] - 0s 195ms/step - loss: 1.3687 - accuracy: 0.4538 - val_loss: 1.3704 - val_accuracy: 0.4138
# Epoch 4/50
# 1/1 [==============================] - 0s 148ms/step - loss: 1.3602 - accuracy: 0.5000 - val_loss: 1.3642 - val_accuracy: 0.5517
# Epoch 5/50
# 1/1 [==============================] - 0s 154ms/step - loss: 1.3517 - accuracy: 0.6385 - val_loss: 1.3579 - val_accuracy: 0.5517
# Epoch 6/50
# 1/1 [==============================] - 0s 139ms/step - loss: 1.3431 - accuracy: 0.6615 - val_loss: 1.3515 - val_accuracy: 0.5517
# Epoch 7/50
# 1/1 [==============================] - 0s 142ms/step - loss: 1.3343 - accuracy: 0.6808 - val_loss: 1.3449 - val_accuracy: 0.5172
# Epoch 8/50
# 1/1 [==============================] - 0s 141ms/step - loss: 1.3253 - accuracy: 0.6885 - val_loss: 1.3381 - val_accuracy: 0.5172
# Epoch 9/50
# 1/1 [==============================] - 0s 140ms/step - loss: 1.3162 - accuracy: 0.6885 - val_loss: 1.3311 - val_accuracy: 0.5172
# Epoch 10/50
# 1/1 [==============================] - 0s 149ms/step - loss: 1.3067 - accuracy: 0.6923 - val_loss: 1.3239 - val_accuracy: 0.5517
# Epoch 11/50
# 1/1 [==============================] - 0s 134ms/step - loss: 1.2971 - accuracy: 0.7000 - val_loss: 1.3164 - val_accuracy: 0.5517
# Epoch 12/50
# 1/1 [==============================] - 0s 145ms/step - loss: 1.2871 - accuracy: 0.7000 - val_loss: 1.3087 - val_accuracy: 0.5517
# Epoch 13/50
# 1/1 [==============================] - 0s 135ms/step - loss: 1.2768 - accuracy: 0.7038 - val_loss: 1.3007 - val_accuracy: 0.5517
# Epoch 14/50
# 1/1 [==============================] - 0s 143ms/step - loss: 1.2662 - accuracy: 0.7038 - val_loss: 1.2923 - val_accuracy: 0.5862
# Epoch 15/50
# 1/1 [==============================] - 0s 140ms/step - loss: 1.2552 - accuracy: 0.7038 - val_loss: 1.2836 - val_accuracy: 0.5862
# Epoch 16/50
# 1/1 [==============================] - 0s 130ms/step - loss: 1.2438 - accuracy: 0.7077 - val_loss: 1.2745 - val_accuracy: 0.5862
# Epoch 17/50
# 1/1 [==============================] - 0s 132ms/step - loss: 1.2321 - accuracy: 0.7115 - val_loss: 1.2651 - val_accuracy: 0.5862
# Epoch 18/50
# 1/1 [==============================] - 0s 135ms/step - loss: 1.2199 - accuracy: 0.7077 - val_loss: 1.2552 - val_accuracy: 0.5862
# Epoch 19/50
# 1/1 [==============================] - 0s 133ms/step - loss: 1.2073 - accuracy: 0.7192 - val_loss: 1.2449 - val_accuracy: 0.5862
# Epoch 20/50
# 1/1 [==============================] - 0s 132ms/step - loss: 1.1942 - accuracy: 0.7231 - val_loss: 1.2341 - val_accuracy: 0.5862
# Epoch 21/50
# 1/1 [==============================] - 0s 137ms/step - loss: 1.1806 - accuracy: 0.7269 - val_loss: 1.2228 - val_accuracy: 0.5862
# Epoch 22/50
# 1/1 [==============================] - 0s 123ms/step - loss: 1.1665 - accuracy: 0.7308 - val_loss: 1.2111 - val_accuracy: 0.5862
# Epoch 23/50
# 1/1 [==============================] - 0s 131ms/step - loss: 1.1520 - accuracy: 0.7346 - val_loss: 1.1989 - val_accuracy: 0.5862
# Epoch 24/50
# 1/1 [==============================] - 0s 152ms/step - loss: 1.1369 - accuracy: 0.7385 - val_loss: 1.1861 - val_accuracy: 0.5862
# Epoch 25/50
# 1/1 [==============================] - 0s 143ms/step - loss: 1.1213 - accuracy: 0.7423 - val_loss: 1.1729 - val_accuracy: 0.5862
# Epoch 26/50
# 1/1 [==============================] - 0s 148ms/step - loss: 1.1051 - accuracy: 0.7462 - val_loss: 1.1591 - val_accuracy: 0.6552
# Epoch 27/50
# 1/1 [==============================] - 0s 132ms/step - loss: 1.0885 - accuracy: 0.7538 - val_loss: 1.1448 - val_accuracy: 0.6552
# Epoch 28/50
# 1/1 [==============================] - 0s 130ms/step - loss: 1.0713 - accuracy: 0.7577 - val_loss: 1.1299 - val_accuracy: 0.6552
# Epoch 29/50
# 1/1 [==============================] - 0s 137ms/step - loss: 1.0536 - accuracy: 0.7615 - val_loss: 1.1145 - val_accuracy: 0.6897
# Epoch 30/50
# 1/1 [==============================] - 0s 155ms/step - loss: 1.0354 - accuracy: 0.7654 - val_loss: 1.0985 - val_accuracy: 0.6897
# Epoch 31/50
# 1/1 [==============================] - 0s 127ms/step - loss: 1.0167 - accuracy: 0.7654 - val_loss: 1.0821 - val_accuracy: 0.6897
# Epoch 32/50
# 1/1 [==============================] - 0s 152ms/step - loss: 0.9975 - accuracy: 0.7692 - val_loss: 1.0650 - val_accuracy: 0.6897
# Epoch 33/50
# 1/1 [==============================] - 0s 141ms/step - loss: 0.9778 - accuracy: 0.7731 - val_loss: 1.0475 - val_accuracy: 0.6897
# Epoch 34/50
# 1/1 [==============================] - 0s 206ms/step - loss: 0.9577 - accuracy: 0.7769 - val_loss: 1.0295 - val_accuracy: 0.7241
# Epoch 35/50
# 1/1 [==============================] - 0s 259ms/step - loss: 0.9372 - accuracy: 0.8000 - val_loss: 1.0110 - val_accuracy: 0.7241
# Epoch 36/50
# 1/1 [==============================] - 0s 234ms/step - loss: 0.9163 - accuracy: 0.8038 - val_loss: 0.9921 - val_accuracy: 0.7586
# Epoch 37/50
# 1/1 [==============================] - 0s 238ms/step - loss: 0.8951 - accuracy: 0.8038 - val_loss: 0.9728 - val_accuracy: 0.7586
# Epoch 38/50
# 1/1 [==============================] - 0s 221ms/step - loss: 0.8735 - accuracy: 0.8077 - val_loss: 0.9530 - val_accuracy: 0.7586
# Epoch 39/50
# 1/1 [==============================] - 0s 217ms/step - loss: 0.8517 - accuracy: 0.8192 - val_loss: 0.9329 - val_accuracy: 0.7586
# Epoch 40/50
# 1/1 [==============================] - 0s 220ms/step - loss: 0.8297 - accuracy: 0.8192 - val_loss: 0.9125 - val_accuracy: 0.7931
# Epoch 41/50
# 1/1 [==============================] - 0s 236ms/step - loss: 0.8075 - accuracy: 0.8269 - val_loss: 0.8918 - val_accuracy: 0.8276
# Epoch 42/50
# 1/1 [==============================] - 0s 211ms/step - loss: 0.7852 - accuracy: 0.8308 - val_loss: 0.8709 - val_accuracy: 0.8276
# Epoch 43/50
# 1/1 [==============================] - 0s 220ms/step - loss: 0.7629 - accuracy: 0.8308 - val_loss: 0.8498 - val_accuracy: 0.8276
# Epoch 44/50
# 1/1 [==============================] - 0s 211ms/step - loss: 0.7405 - accuracy: 0.8500 - val_loss: 0.8286 - val_accuracy: 0.8276
# Epoch 45/50
# 1/1 [==============================] - 0s 242ms/step - loss: 0.7182 - accuracy: 0.8692 - val_loss: 0.8074 - val_accuracy: 0.8276
# Epoch 46/50
# 1/1 [==============================] - 0s 264ms/step - loss: 0.6960 - accuracy: 0.8769 - val_loss: 0.7861 - val_accuracy: 0.8276
# Epoch 47/50
# 1/1 [==============================] - 0s 222ms/step - loss: 0.6740 - accuracy: 0.8846 - val_loss: 0.7649 - val_accuracy: 0.8276
# Epoch 48/50
# 1/1 [==============================] - 0s 237ms/step - loss: 0.6521 - accuracy: 0.8846 - val_loss: 0.7438 - val_accuracy: 0.8276
# Epoch 49/50
# 1/1 [==============================] - 0s 219ms/step - loss: 0.6306 - accuracy: 0.8846 - val_loss: 0.7228 - val_accuracy: 0.8276
# Epoch 50/50
# 1/1 [==============================] - 0s 235ms/step - loss: 0.6093 - accuracy: 0.8846 - val_loss: 0.7021 - val_accuracy: 0.8276
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 79, 100)           98400
#
#  gru_1 (GRU)                 (None, 16)                5664
#
#  dense_26 (Dense)            (None, 4)                 68
#
# =================================================================
# Total params: 104,132
# Trainable params: 104,132
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: user 18.2 s, sys: 791 ms, total: 19 s
# Wall time: 27.5 s

# %%
#CNN

def build_cnn_model(embed_dim, filters, ksize, strides):

    model = Sequential([
        Embedding(
            VOCAB_SIZE + 1,
            embed_dim,
            input_shape=[MAX_LEN],
            mask_zero=True),
        Conv1D( 
            filters=filters,
            kernel_size=ksize,
            strides=strides,
            activation='relu',
        ),
        Flatten(), 
        Dense(N_CLASSES, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# %%time

tf.random.set_seed(33) 

MODEL_DIR = os.path.join(LOGDIR, 'cnn')
shutil.rmtree(MODEL_DIR, ignore_errors=True)

EPOCHS = 50
BATCH_SIZE = 300
EMBED_DIM = 100
FILTERS = 200
STRIDES = 2
KSIZE = 3
PATIENCE = 0


cnn_model = build_cnn_model(
    embed_dim=EMBED_DIM,
    filters=FILTERS,
    strides=STRIDES,
    ksize=KSIZE,
)

cnn_history = cnn_model.fit(
    X_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_valid, y_valid),
    callbacks=[EarlyStopping(patience=PATIENCE), TensorBoard(MODEL_DIR)],
)

pd.DataFrame(cnn_history.history)[['loss', 'val_loss']].plot()
pd.DataFrame(cnn_history.history)[['accuracy', 'val_accuracy']].plot()

cnn_model.summary()
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.3897 - accuracy: 0.2769 - val_loss: 1.3653 - val_accuracy: 0.2759
# Epoch 2/50
# 1/1 [==============================] - 0s 146ms/step - loss: 1.3552 - accuracy: 0.2962 - val_loss: 1.3469 - val_accuracy: 0.4138
# Epoch 3/50
# 1/1 [==============================] - 0s 139ms/step - loss: 1.3245 - accuracy: 0.5308 - val_loss: 1.3281 - val_accuracy: 0.4483
# Epoch 4/50
# 1/1 [==============================] - 0s 138ms/step - loss: 1.2945 - accuracy: 0.5500 - val_loss: 1.3055 - val_accuracy: 0.4138
# Epoch 5/50
# 1/1 [==============================] - 0s 148ms/step - loss: 1.2631 - accuracy: 0.5423 - val_loss: 1.2760 - val_accuracy: 0.4828
# Epoch 6/50
# 1/1 [==============================] - 0s 135ms/step - loss: 1.2279 - accuracy: 0.5846 - val_loss: 1.2395 - val_accuracy: 0.5517
# Epoch 7/50
# 1/1 [==============================] - 0s 135ms/step - loss: 1.1882 - accuracy: 0.6346 - val_loss: 1.1964 - val_accuracy: 0.5862
# Epoch 8/50
# 1/1 [==============================] - 0s 147ms/step - loss: 1.1438 - accuracy: 0.6923 - val_loss: 1.1478 - val_accuracy: 0.6552
# Epoch 9/50
# 1/1 [==============================] - 0s 200ms/step - loss: 1.0956 - accuracy: 0.7654 - val_loss: 1.0949 - val_accuracy: 0.6897
# Epoch 10/50
# 1/1 [==============================] - 0s 292ms/step - loss: 1.0440 - accuracy: 0.8115 - val_loss: 1.0400 - val_accuracy: 0.7931
# Epoch 11/50
# 1/1 [==============================] - 0s 253ms/step - loss: 0.9902 - accuracy: 0.8385 - val_loss: 0.9857 - val_accuracy: 0.8276
# Epoch 12/50
# 1/1 [==============================] - 0s 239ms/step - loss: 0.9353 - accuracy: 0.8423 - val_loss: 0.9331 - val_accuracy: 0.8621
# Epoch 13/50
# 1/1 [==============================] - 0s 279ms/step - loss: 0.8794 - accuracy: 0.8385 - val_loss: 0.8823 - val_accuracy: 0.8276
# Epoch 14/50
# 1/1 [==============================] - 0s 312ms/step - loss: 0.8224 - accuracy: 0.8308 - val_loss: 0.8348 - val_accuracy: 0.7931
# Epoch 15/50
# 1/1 [==============================] - 0s 208ms/step - loss: 0.7667 - accuracy: 0.8308 - val_loss: 0.7901 - val_accuracy: 0.7931
# Epoch 16/50
# 1/1 [==============================] - 0s 241ms/step - loss: 0.7146 - accuracy: 0.8308 - val_loss: 0.7451 - val_accuracy: 0.7586
# Epoch 17/50
# 1/1 [==============================] - 0s 240ms/step - loss: 0.6657 - accuracy: 0.8308 - val_loss: 0.7003 - val_accuracy: 0.7586
# Epoch 18/50
# 1/1 [==============================] - 0s 231ms/step - loss: 0.6190 - accuracy: 0.8346 - val_loss: 0.6593 - val_accuracy: 0.8276
# Epoch 19/50
# 1/1 [==============================] - 0s 236ms/step - loss: 0.5746 - accuracy: 0.8346 - val_loss: 0.6266 - val_accuracy: 0.8276
# Epoch 20/50
# 1/1 [==============================] - 0s 225ms/step - loss: 0.5335 - accuracy: 0.8577 - val_loss: 0.6020 - val_accuracy: 0.8621
# Epoch 21/50
# 1/1 [==============================] - 0s 275ms/step - loss: 0.4941 - accuracy: 0.8731 - val_loss: 0.5792 - val_accuracy: 0.8621
# Epoch 22/50
# 1/1 [==============================] - 0s 225ms/step - loss: 0.4549 - accuracy: 0.8731 - val_loss: 0.5539 - val_accuracy: 0.8276
# Epoch 23/50
# 1/1 [==============================] - 0s 250ms/step - loss: 0.4168 - accuracy: 0.8846 - val_loss: 0.5249 - val_accuracy: 0.8276
# Epoch 24/50
# 1/1 [==============================] - 0s 228ms/step - loss: 0.3794 - accuracy: 0.8923 - val_loss: 0.4955 - val_accuracy: 0.8621
# Epoch 25/50
# 1/1 [==============================] - 0s 259ms/step - loss: 0.3423 - accuracy: 0.9000 - val_loss: 0.4696 - val_accuracy: 0.8621
# Epoch 26/50
# 1/1 [==============================] - 0s 213ms/step - loss: 0.3061 - accuracy: 0.9038 - val_loss: 0.4474 - val_accuracy: 0.8966
# Epoch 27/50
# 1/1 [==============================] - 0s 237ms/step - loss: 0.2709 - accuracy: 0.9385 - val_loss: 0.4263 - val_accuracy: 0.9310
# Epoch 28/50
# 1/1 [==============================] - 0s 206ms/step - loss: 0.2379 - accuracy: 0.9462 - val_loss: 0.4014 - val_accuracy: 0.9310
# Epoch 29/50
# 1/1 [==============================] - 0s 231ms/step - loss: 0.2070 - accuracy: 0.9654 - val_loss: 0.3719 - val_accuracy: 0.9310
# Epoch 30/50
# 1/1 [==============================] - 0s 195ms/step - loss: 0.1777 - accuracy: 0.9731 - val_loss: 0.3423 - val_accuracy: 0.9310
# Epoch 31/50
# 1/1 [==============================] - 0s 240ms/step - loss: 0.1514 - accuracy: 0.9769 - val_loss: 0.3162 - val_accuracy: 0.9310
# Epoch 32/50
# 1/1 [==============================] - 0s 230ms/step - loss: 0.1281 - accuracy: 0.9923 - val_loss: 0.2942 - val_accuracy: 0.9310
# Epoch 33/50
# 1/1 [==============================] - 0s 210ms/step - loss: 0.1072 - accuracy: 1.0000 - val_loss: 0.2752 - val_accuracy: 0.9310
# Epoch 34/50
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0892 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9310
# Epoch 35/50
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.2383 - val_accuracy: 0.9310
# Epoch 36/50
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.2198 - val_accuracy: 0.9655
# Epoch 37/50
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0498 - accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9655
# Epoch 38/50
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9655
# Epoch 39/50
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.1735 - val_accuracy: 0.9655
# Epoch 40/50
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.9655
# Epoch 41/50
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9655
# Epoch 42/50
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9655
# Epoch 43/50
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9655
# Epoch 44/50
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9655
# Epoch 45/50
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9655
# Epoch 46/50
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9655
# Epoch 47/50
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.1091 - val_accuracy: 0.9655
# Epoch 48/50
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9655
# Epoch 49/50
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0989 - val_accuracy: 0.9655
# Epoch 50/50
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9655
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, 79, 100)           98400
#
#  conv1d_1 (Conv1D)           (None, 39, 200)           60200
#
#  flatten_1 (Flatten)         (None, 7800)              0
#
#  dense_27 (Dense)            (None, 4)                 31204
#
# =================================================================
# Total params: 189,804
# Trainable params: 189,804
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: user 11.8 s, sys: 660 ms, total: 12.5 s
# Wall time: 11.3 s

# %%
def convert_argmax(array):
    return np.argmax(array, axis=1)

menu = {0:"아이스 아메리카노", 1: "따뜻한 아메리카노", 2: "콜드브루", 3: "카라멜마끼아또"}

# %%
test = ["시원한", "카라멜", "따뜻한", "시원한 음료"]

# %%
print("***********************DNN******************************")
x_text = create_sequences(test)
result = dnn_model.predict(x_text)
#print(result)
#print(convert_argmax(result))
for i in convert_argmax(result):
  print(menu[i])
# Out:
# ***********************DNN******************************
# 1/1 [==============================] - 0s 34ms/step
# 콜드브루
# 콜드브루
# 콜드브루
# 콜드브루

# %%
print("***********************CNN******************************")
x_text = create_sequences(test)
result = cnn_model.predict(x_text)
#print(result)
#print(convert_argmax(result))
for i in convert_argmax(result):
  print(menu[i])
# Out:
# ***********************CNN******************************
# 1/1 [==============================] - 0s 24ms/step
# 아이스 아메리카노
# 아이스 아메리카노
# 아이스 아메리카노
# 아이스 아메리카노

# %%
print("***********************RNN******************************")
x_text = create_sequences(test)
result = rnn_model.predict(x_text)
#print(result)
#print(convert_argmax(result))
for i in convert_argmax(result):
  print(menu[i])
# Out:
# ***********************RNN******************************
# 1/1 [==============================] - 0s 46ms/step
# 콜드브루
# 카라멜마끼아또
# 따뜻한 아메리카노
# 카라멜마끼아또
